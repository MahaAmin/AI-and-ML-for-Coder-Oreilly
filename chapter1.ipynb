# %% [markdown]
# # AI and ML for Coders - TensorFlow

# %% [markdown]
# ## Chapter 1: Introduction To TensorFlow

# %% [markdown]
# ### Learning Notes

# %% [markdown]
# - Installing tensorFlow using pip and PyCharm
# - Use tensorflow in Jupyter Notebooks and pyCharm.
# - Simple linear equation prediction (Y=2X-1).
# - Introduction to tensorflow.keras APIs.
# - Using "Sequential" for defining a neural netwrk layers.
# - Using "Dense" which is one type of keras.layers types. It means "fully connected" neurons.
# - "sgd": Sochastic Gradient Descent.
# - "Y=BX-C": B:weight, C:Bias.

# %%
import tensorflow as tf
# Out:
# 2022-01-17 04:33:11.425128: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-17 04:33:11.425157: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
print(tf.__version__)
# Out:
# 2.7.0

# %%
import tensorflow as tf
import numpy as np 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
print("Here's what I learned: {}".format(model.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 172ms/step - loss: 53.1402
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 42.2140
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 33.6095
# Epoch 4/500
# 1/1 [==============================] - 0s 20ms/step - loss: 26.8318
# Epoch 5/500
# 1/1 [==============================] - 0s 12ms/step - loss: 21.4914
# Epoch 6/500
# 1/1 [==============================] - 0s 12ms/step - loss: 17.2819
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 13.9625
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 11.3434
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2755
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.6413
# Epoch 11/500
# 1/1 [==============================] - 0s 25ms/step - loss: 6.3486
# Epoch 12/500
# ...
